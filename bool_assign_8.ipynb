# %%
print("Question 1: Check if 25 is greater than 20 and less than 30")
a=25
b=20
c=30
if a>b<c:
    print(True)
# Out:
# Question 1: Check if 25 is greater than 20 and less than 30
# True

# %%
print("Question 2: Check if string (python) is equal to (Python)")
d="python"
e="Python"
is_equal=(d==e)
is_equal
# Out:
# Question 2: Check if string (python) is equal to (Python)
# False

# %%
print("Question 3: Check if 15 is divisible by both 3 and 5")
f=15
g=3
h=5
divisible = (f/g) , (f/h)
divisible
# Out:
# Question 3: Check if 15 is divisible by both 3 and 5
# (5.0, 3.0)

# %%
print("Question 4: Check if 7 is not equal to 8")
i=7
j=8
i!=8
# Out:
# Question 4: Check if 7 is not equal to 8
# True

# %%
print("Question 5: Check if 100 is greater than 50 or less than 25")
check_greater_lessthan=50<100 or 100<25
check_greater_lessthan
# Out:
# Question 5: Check if 100 is greater than 50 or less than 25
# True

# %%
print("Question 6: Check if 0 is falsy in Python")
result=bool(0)
result
# Out:
# Question 6: Check if 0 is falsy in Python
# False

# %%
print"(Question 7: Check if empty string "" is falsy in Python
empty_string=""
bool(empty_string)
# Out:
# False

# %%
print("Question 8: Check if 42 is truthy in Python")
check_truthy=42
bool(check_truthy)
# Out:
# Question 8: Check if 42 is truthy in Python
# True

# %%
print("Question 9: Check if 10 is between 5 and 15 (inclusive)")
check_between= 5<=10<=15
check_between

# or

# is_10_between=5<=10 and 10<=15
# is_10_between
# Out:
# Question 9: Check if 10 is between 5 and 15 (inclusive)
# True

# %%
print("Question 10: Check if 3.14 is greater than 3 and less than 4")
greater_than_lessthan=(3.14>3) or (3.14<4)
greater_than_lessthan
# Out:
# Question 10: Check if 3.14 is greater than 3 and less than 4
# True
