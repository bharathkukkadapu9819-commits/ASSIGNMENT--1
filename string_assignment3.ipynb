# %%
string="Python Programming"
reverse_string=string[::-1]
print("1st.",reverse_string)
# Out:
# 1st. gnimmargorP nohtyP

# %%
palindrome_check="racercar"
print("2nd.", palindrome_check[::-1])
# Out:
# 2nd. racrecar

# %%
split_words="Python is a great programming language"
count_words=split_words.split()
print("3rd." ,len(count_words))
# count_words
# Out:
# 3rd. 6

# %%
text="hello world"
new_text=text.title()
print("4th." , new_text)
# Out:
# 4th. Hello World

# %%
data_sci_length="Data Science"
print("5th." ,len("Data Science"))
# Out:
# 5th. 12

# %%
course_given="Machine Learning"
split_course=course_given.replace(" " , "_")
print("6th." , split_course)
# Out:
# 6th. Machine_Learning

# %%
is_python_in="Python Programming Language"
check_for_python="Python" in is_python_in
print("7th." , check_for_python)
# Out:
# 7th. True

# %%
AI_given="Artificial Intelligence"
extracting_first_five=AI_given[:5]
print("8th." , extracting_first_five)
# Out:
# 8th. Artif

# %%
given_UPPERCASE="UPPERCASE"
to_lower_case=given_UPPERCASE.lower()
print("9th.",to_lower_case)
# Out:
# 9th. uppercase

# %%
data= "Computer Science"
for i in "aeiouAEIOU":
    data=data.replace(i, "")
print("10th." ,data)
# Out:
# 10th. Cmptr Scnc

# %%
Capatilize_1st_word="python programming language"
print("13th." , Capatilize_1st_word.title())
# Out:
# 13th. Python Programming Language

# %%
count_consonants="Hello World"
for i in "aeiouAEIOU":
    count_consonants=count_consonants.replace(i,"")
new_word=count_consonants.replace(" " , "")
print("14th." , new_word, ":", len(new_word))
# Out:
# 14th. HllWrld : 7

# %%
text="python is a programming language"
shortest_word=max(text.split() , key=len)
print("15th." ,shortest_word)
# Out:
# 15th. programming

# %%
greetings="Hello, World! How are you?"
for i in ",!?":
    greetings=greetings.replace(i,"")
print("16th." , greetings)
# Out:
# 16th. Hello World How are you

# %%
check_starts_with="Python"
chck_python_starts=check_starts_with.startswith("Python")
print(f"17th. CHECK PYTHON STARTS WITH: {chck_python_starts}")
# Out:
# 17th. CHECK PYTHON STARTS WITH: True

# %%
occurence_of_O="Hello World"
index_first_O=occurence_of_O.index("o")
print(f"18th.  {index_first_O}")
# Out:
# 18th.  4

# %%
string="apple,banana,orange"
split_string=string.split(",")
print(f"19th. {split_string}")
# Out:
# 19th. ['apple', 'banana', 'orange']

# %%
joininng_list=" ".join(['Python', 'is', 'awesome'])
print(f"20th.  {joininng_list}")
# Out:
# 20th.  Python is awesome

# %%
digits="12345"
check_digits=digits.isdigit()
print("21st." ,check_digits)
# Out:
# 21st. True

# %%
alphabets="HelloWorld"
check_only_lettrs=alphabets.isalpha()
print("22nd." , check_only_lettrs)
# Out:
# 22nd. True

# %%
dite="banana"
dite.split()
print(dite.index("a"))
print(dite.index("a" , 2))
print("24th." ,dite.index("a" , 4))
# Out:
# 1
# 3
# 24th. 5

# %%
strip_l_r="  Hello World  "
stripping_of=strip_l_r.strip()
print("25th." , stripping_of)
# Out:
# 25th. Hello World

# %%
string_ends_with="programming"
print("26th." ,string_ends_with.endswith("ing"))
# Out:
# 26th. True

# %%
S_27= "Hello World"
first_word=S_27[:5][:6]
second_word=S_27[6:]
new_word=first_word.replace("o" , "0")
first_occurence=new_word+" "+second_word
print("27th." , first_occurence)
# Out:
# 27th. Hell0 World

# %%
text="python is a programming language"
shortest_word=min(text.split(),key=len)
print("28th." , shortest_word)
# Out:
# 28th. a

# %%
data="Hello World Python"
newdata=data.split()
reverse=newdata[::-1]
print("30th." , reverse)
# Out:
# 30th. ['Python', 'World', 'Hello']

# %%
mail="user@example.com"
if mail.endswith(".com"):
    print("31st." ,True)
# Out:
# 31st. True

# %%
domain="https://www.example.com/path"
newdomain=domain.split("/")
print("32nd." , newdomain[2])
# Out:
# 32nd. www.example.com

# %%
multi_line_string=""" once upon a time 
there lived a ghost
that is scary
ijncfpoa"""
print("33rd." ,len(multi_line_string.splitlines()))
# Out:
# 33rd. 4

# %%
phone_number="+1-555-123-4567"
print("35th." , phone_number.isascii())
# Out:
# 35th. True

# %%
extract="abc123def456ghi789"
for alphabets in "abcdefghijklmnopqrstuvwxyz":
    extract=extract.replace(alphabets , "")
print("36th." , extract)
# Out:
# 36th. 123456789

# %%
case="snake_case"
case1=case[:5]
case_change1=case1.replace("snake" , "camel")
case2=case[6:]
case_change2=case2.replace("c" ,"C")
casechange=case_change1+case_change2
print("37TH.BELOW IS THE ANSWER : ")
print(casechange)

# or

print(case.title())
# Out:
# 37TH.BELOW IS THE ANSWER :
# camelCase
# Snake_Case

# %%
palindrome_ignoring_case="A man a plan a canal Panama"
replace=palindrome_ignoring_case.replace(" ","")
print("38th." , replace[::-1])
# Out:
# 38th. amanaPlanacanalpanamA
